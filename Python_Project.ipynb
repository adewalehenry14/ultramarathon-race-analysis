# %% [markdown]
# <a href="https://colab.research.google.com/github/adewalehenry14/ultramarathon-race-analysis/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/Two_Centuries Races.csv.csv')
df.head(10)
# Out:
# /tmp/ipykernel_144/842918972.py:5: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Two_Centuries Races.csv.csv')
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                       22.0           4:51:39 h                Tnfrc
# 1                       22.0           5:15:45 h   Roberto Echeverría
# 2                       22.0           5:16:44 h    Puro Trail Osorno
# 3                       22.0           5:34:13 h             Columbia
# 4                       22.0           5:54:14 h       Baguales Trail
# 5                       22.0           6:25:01 h                  NaN
# 6                       22.0           6:28:00 h        Los Patagones
# 7                       22.0           6:32:24 h       Reaktiva Chile
# 8                       22.0           6:39:08 h    Puro Trail Osorno
# 9                       22.0           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286         0.0
# 1                 9.501         1.0
# 2                 9.472         2.0
# 3                 8.976         3.0
# 4                 8.469         4.0
# 5                 7.792         5.0
# 6                 7.732         6.0
# 7                 7.645         7.0
# 8                 7.516         8.0
# 9                 7.404         9.0

# %%
df.shape
# Out:
# (951560, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %%
##Data Cleanup
##Only Usa Races,50k or 50mi, 2020

##Show 50km or 50mi

#df[df['Event distance/length'] == '50km']
df[df['Event distance/length'] == '50mi']
# Out:
#         Year of event Event dates  \
# 55               2018  06.01.2018
# 56               2018  06.01.2018
# 57               2018  06.01.2018
# 58               2018  06.01.2018
# 59               2018  06.01.2018
# ...               ...         ...
# 951554           2016  27.08.2016
# 951555           2016  27.08.2016
# 951556           2016  27.08.2016
# 951557           2016  27.08.2016
# 951558           2016  27.08.2016
#
#                                            Event name Event distance/length  \
# 55      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                               ...                   ...
# 951554       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951555       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951556       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951557       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951558       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
#
#         Event number of finishers Athlete performance          Athlete club  \
# 55                            9.0           9:53:05 h      *Middleville, MI
# 56                            9.0          11:09:35 h         *Waterloo, ON
# 57                            9.0          11:33:00 h        *Kitchener, ON
# 58                            9.0          11:38:17 h            *Utica, MI
# 59                            9.0          11:56:35 h       *Grass Lake, MI
# ...                           ...                 ...                   ...
# 951554                       31.0          12:15:02 h           *Butler, PA
# 951555                       31.0          12:19:02 h       *Pittsburgh, PA
# 951556                       31.0          12:31:47 h      *Islip, New York
# 951557                       31.0          12:34:53 h  *Natrona Heights, PA
# 951558                       31.0          12:48:42 h           *Dubois, PA
#
#        Athlete country  Athlete year of birth Athlete gender  \
# 55                 USA                 1983.0              M
# 56                 CAN                 1977.0              F
# 57                 CAN                 1976.0              M
# 58                 USA                 1986.0              M
# 59                 USA                 1988.0              M
# ...                ...                    ...            ...
# 951554             USA                 1971.0              M
# 951555             USA                 1972.0              M
# 951556             USA                 1982.0              M
# 951557             USA                 1968.0              M
# 951558             USA                 1975.0              M
#
#        Athlete age category Athlete average speed  Athlete ID
# 55                      M23                 8.141        55.0
# 56                      W40                 7.211        56.0
# 57                      M40                 6.967        57.0
# 58                      M23                 6.914        58.0
# 59                      M23                 6.738        59.0
# ...                     ...                   ...         ...
# 951554                  M40                 6.568    208615.0
# 951555                  M40                 6.533    291884.0
# 951556                  M23                 6.422    119313.0
# 951557                  M45                 6.396     25599.0
# 951558                  M40                 6.281    177812.0
#
# [31953 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#         Year of event Event dates                                Event name  \
# 0                2018  06.01.2018                       Selva Costera (CHI)
# 1                2018  06.01.2018                       Selva Costera (CHI)
# 2                2018  06.01.2018                       Selva Costera (CHI)
# 3                2018  06.01.2018                       Selva Costera (CHI)
# 4                2018  06.01.2018                       Selva Costera (CHI)
# ...               ...         ...                                       ...
# 951554           2016  27.08.2016  Baker Trail 50 Mile UltraChallenge (USA)
# 951555           2016  27.08.2016  Baker Trail 50 Mile UltraChallenge (USA)
# 951556           2016  27.08.2016  Baker Trail 50 Mile UltraChallenge (USA)
# 951557           2016  27.08.2016  Baker Trail 50 Mile UltraChallenge (USA)
# 951558           2016  27.08.2016  Baker Trail 50 Mile UltraChallenge (USA)
#
#        Event distance/length  Event number of finishers Athlete performance  \
# 0                       50km                       22.0           4:51:39 h
# 1                       50km                       22.0           5:15:45 h
# 2                       50km                       22.0           5:16:44 h
# 3                       50km                       22.0           5:34:13 h
# 4                       50km                       22.0           5:54:14 h
# ...                      ...                        ...                 ...
# 951554                  50mi                       31.0          12:15:02 h
# 951555                  50mi                       31.0          12:19:02 h
# 951556                  50mi                       31.0          12:31:47 h
# 951557                  50mi                       31.0          12:34:53 h
# 951558                  50mi                       31.0          12:48:42 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 0                      Tnfrc             CHI                 1978.0
# 1         Roberto Echeverría             CHI                 1981.0
# 2          Puro Trail Osorno             CHI                 1987.0
# 3                   Columbia             ARG                 1976.0
# 4             Baguales Trail             CHI                 1992.0
# ...                      ...             ...                    ...
# 951554           *Butler, PA             USA                 1971.0
# 951555       *Pittsburgh, PA             USA                 1972.0
# 951556      *Islip, New York             USA                 1982.0
# 951557  *Natrona Heights, PA             USA                 1968.0
# 951558           *Dubois, PA             USA                 1975.0
#
#        Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                   M                  M35                10.286         0.0
# 1                   M                  M35                 9.501         1.0
# 2                   M                  M23                 9.472         2.0
# 3                   M                  M40                 8.976         3.0
# 4                   M                  M23                 8.469         4.0
# ...               ...                  ...                   ...         ...
# 951554              M                  M40                 6.568    208615.0
# 951555              M                  M40                 6.533    291884.0
# 951556              M                  M23                 6.422    119313.0
# 951557              M                  M45                 6.396     25599.0
# 951558              M                  M40                 6.281    177812.0
#
# [249638 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)'] ['Event name'].str.split('(').str.get(1).str.split('(').str.get(0)
# Out:
# 51923     USA)
# 51924     USA)
# 51925     USA)
# 51926     USA)
# 51927     USA)
#           ...
# 692653    USA)
# 692654    USA)
# 692655    USA)
# 692656    USA)
# 692657    USA)
# Name: Event name, Length: 67, dtype: object

# %%
###Shows all events that took placein the USA
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#         Year of event Event dates  \
# 55               2018  06.01.2018
# 56               2018  06.01.2018
# 57               2018  06.01.2018
# 58               2018  06.01.2018
# 59               2018  06.01.2018
# ...               ...         ...
# 951554           2016  27.08.2016
# 951555           2016  27.08.2016
# 951556           2016  27.08.2016
# 951557           2016  27.08.2016
# 951558           2016  27.08.2016
#
#                                            Event name Event distance/length  \
# 55      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59      Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                               ...                   ...
# 951554       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951555       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951556       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951557       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
# 951558       Baker Trail 50 Mile UltraChallenge (USA)                  50mi
#
#         Event number of finishers Athlete performance          Athlete club  \
# 55                            9.0           9:53:05 h      *Middleville, MI
# 56                            9.0          11:09:35 h         *Waterloo, ON
# 57                            9.0          11:33:00 h        *Kitchener, ON
# 58                            9.0          11:38:17 h            *Utica, MI
# 59                            9.0          11:56:35 h       *Grass Lake, MI
# ...                           ...                 ...                   ...
# 951554                       31.0          12:15:02 h           *Butler, PA
# 951555                       31.0          12:19:02 h       *Pittsburgh, PA
# 951556                       31.0          12:31:47 h      *Islip, New York
# 951557                       31.0          12:34:53 h  *Natrona Heights, PA
# 951558                       31.0          12:48:42 h           *Dubois, PA
#
#        Athlete country  Athlete year of birth Athlete gender  \
# 55                 USA                 1983.0              M
# 56                 CAN                 1977.0              F
# 57                 CAN                 1976.0              M
# 58                 USA                 1986.0              M
# 59                 USA                 1988.0              M
# ...                ...                    ...            ...
# 951554             USA                 1971.0              M
# 951555             USA                 1972.0              M
# 951556             USA                 1982.0              M
# 951557             USA                 1968.0              M
# 951558             USA                 1975.0              M
#
#        Athlete age category Athlete average speed  Athlete ID
# 55                      M23                 8.141        55.0
# 56                      W40                 7.211        56.0
# 57                      M40                 6.967        57.0
# 58                      M23                 6.914        58.0
# 59                      M23                 6.738        59.0
# ...                     ...                   ...         ...
# 951554                  M40                 6.568    208615.0
# 951555                  M40                 6.533    291884.0
# 951556                  M23                 6.422    119313.0
# 951557                  M45                 6.396     25599.0
# 951558                  M40                 6.281    177812.0
#
# [148415 rows x 13 columns]

# %%
df[
    (df['Event distance/length'].isin(['50km', '50mi'])) &
    (df['Year of event'] == 2020) &
    (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')
]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
df2 = df[
    (df['Event distance/length'].isin(['50km', '50mi'])) &
    (df['Year of event'] == 2020) &
    (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')
]
df2.head()
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
df2.shape
# Out:
# (0, 13)

# %%
##remove [USA] from event name
df2['Event name'].str.split('(').str.get(0)
# Out:
# Series([], Name: Event name, dtype: object)

# %%
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)

# %%
##USA is gone
df2.head()
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID]
# Index: []

# %%
##Athlete age cleanup
df2['athlete_age'] = 2020 - df2['Athlete year of birth']

# %%
##remove  h from athlete performance
df2['Athlete performance'] = df2['Athlete performance'].str.split('(').str.get(0)

# %%
df2.head(5)
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete club, Athlete country, Athlete year of birth, Athlete gender, Athlete age category, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
df2.columns
# Out:
# Index(['Year of event', 'Event dates', 'Event name', 'Event distance/length',
#        'Event number of finishers', 'Athlete performance', 'Athlete club',
#        'Athlete country', 'Athlete year of birth', 'Athlete gender',
#        'Athlete age category', 'Athlete average speed', 'Athlete ID',
#        'athlete_age'],
#       dtype='object')

# %%
##drop columns: Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category
df2 = df2.drop(columns=['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
##Clean up null values
df2.isna().sum()
# Out:
# Year of event                0
# Event dates                  0
# Event name                   0
# Event distance/length        0
# Event number of finishers    0
# Athlete performance          0
# Athlete gender               0
# Athlete average speed        0
# Athlete ID                   0
# athlete_age                  0
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
df2 = df2.dropna()
df2.shape
# Out:
# (0, 10)

# %%
##Check for duplicated
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
##reset {index
df2.reset_index(drop = True)
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
##fix types
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed         object
# Athlete ID                   float64
# athlete_age                  float64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
#average speed
df2['Athlete average speed'] = df2['Athlete average speed'].astype(float)

# %%
df2.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers    float64
# Athlete performance           object
# Athlete gender                object
# Athlete average speed        float64
# Athlete ID                   float64
# athlete_age                    int64
# dtype: object

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [Year of event, Event dates, Event name, Event distance/length, Event number of finishers, Athlete performance, Athlete gender, Athlete average speed, Athlete ID, athlete_age]
# Index: []

# %%
##rename columns
#Year of event 	int64
#Event dates 	object
#Event name 	object
#Event distance/length 	object
#Event number of finishers 	int64
#Athlete performance 	object
#Athlete gender 	object
#Athlete average speed 	float64
#Athlete ID 	int64
#athlete_age 	int64

# %%
df2 = df2.rename(columns = {'Year of event': 'year',
                            'Event dates': 'race_day',
                            'Event name': 'race_name',
                            'Event distance/length': 'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id',
                            })

# %%
df2.head()
# Out:
# Empty DataFrame
# Columns: [year, race_day, race_name, race_length, race_number_of_finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete_age]
# Index: []

# %%
df2.columns
# Out:
# Index(['year', 'race_day', 'race_name', 'race_length',
#        'race_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_average_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
#reorder columns
df3 = df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
# Empty DataFrame
# Columns: [race_day, race_name, race_length, race_number_of_finishers, athlete_id, athlete_gender, athlete_age, athlete_performance, athlete_average_speed]
# Index: []

# %%
#charts and graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: >

# %%
#to overlay males vs females
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_144/3143143206.py in <cell line: 0>()
#       1 #to overlay males vs females
# ----> 2 sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in histplot(data, x, y, hue, weights, stat, bins, binwidth, binrange, discrete, cumulative, common_bins, common_norm, multiple, element, fill, shrink, kde, kde_kws, line_kws, thresh, pthresh, pmax, cbar, cbar_ax, cbar_kws, palette, hue_order, hue_norm, color, log_scale, legend, ax, **kwargs)
#    1414     if p.univariate:
#    1415
# -> 1416         p.plot_univariate_histogram(
#    1417             multiple=multiple,
#    1418             element=element,
#
# /usr/local/lib/python3.12/dist-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     663
#     664             # We will base everything on the minimum bin width
# --> 665             hist_metadata = pd.concat([
#     666                 # Use .items for generality over dict or df
#     667                 h.index.to_frame() for _, h in histograms.items()
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     380         copy = False
#     381
# --> 382     op = _Concatenator(
#     383         objs,
#     384         axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     443         self.copy = copy
#     444
# --> 445         objs, keys = self._clean_keys_and_objs(objs, keys)
#     446
#     447         # figure out what our result ndim is going to be
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/reshape/concat.py in _clean_keys_and_objs(self, objs, keys)
#     505
#     506         if len(objs_list) == 0:
# --> 507             raise ValueError("No objects to concatenate")
#     508
#     509         if keys is None:
#
# ValueError: No objects to concatenate

# %%
sns.displot(df3[df3['race_length'] == '50mi'] ['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quarts', linewidth = 1)

# %%
sns.lmplot(data=df3, x= 'athlete_age', y= 'athlete_average_speed', hue = 'athlete_gender')

# %%
#questions I want to find out from the data
##rename columns
#Year of event 	int64
#Event dates 	object
#Event name 	object
#Event distance/length 	object
#Event number of finishers 	int64
#Athlete performance 	object
#Athlete gender 	object
#Athlete average speed 	float64
#Athlete ID 	int64
#athlete_age 	int64

# %%
#Difference in speed for the 50k,50mi male to female

# %%
df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# Series([], Name: athlete_average_speed, dtype: float64)

# %%
#what age groups are the best in the 50m race? (20 + races min) show 15

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count > 19').head(15)

# %%
#what age groups are the worst in the 50m race? (10 + races min) show 20

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count > 9').head(20)

# %%
#seasons for the data -> Slower in summer than winter?

#spring 3-5
#summer 6-8
#fall 9-11
#winter 12-2

#aplit between two decimals

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
#Race seasons
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')
df3.head(25)

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)

# %%
#50 miler only
df3.query('`race_length` == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
