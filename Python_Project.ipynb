# %% [markdown]
# <a href="https://colab.research.google.com/github/adewalehenry14/ultramarathon-race-analysis/blob/main/Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

df = pd.read_csv('/content/Two_Centuries Races.csv.csv')
df.head(10)
# Out:
# /tmp/ipykernel_12380/842918972.py:5: DtypeWarning: Columns (11) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/Two_Centuries Races.csv.csv')
#    Year of event Event dates           Event name Event distance/length  \
# 0           2018  06.01.2018  Selva Costera (CHI)                  50km
# 1           2018  06.01.2018  Selva Costera (CHI)                  50km
# 2           2018  06.01.2018  Selva Costera (CHI)                  50km
# 3           2018  06.01.2018  Selva Costera (CHI)                  50km
# 4           2018  06.01.2018  Selva Costera (CHI)                  50km
# 5           2018  06.01.2018  Selva Costera (CHI)                  50km
# 6           2018  06.01.2018  Selva Costera (CHI)                  50km
# 7           2018  06.01.2018  Selva Costera (CHI)                  50km
# 8           2018  06.01.2018  Selva Costera (CHI)                  50km
# 9           2018  06.01.2018  Selva Costera (CHI)                  50km
#
#    Event number of finishers Athlete performance         Athlete club  \
# 0                         22           4:51:39 h                Tnfrc
# 1                         22           5:15:45 h   Roberto Echeverría
# 2                         22           5:16:44 h    Puro Trail Osorno
# 3                         22           5:34:13 h             Columbia
# 4                         22           5:54:14 h       Baguales Trail
# 5                         22           6:25:01 h                  NaN
# 6                         22           6:28:00 h        Los Patagones
# 7                         22           6:32:24 h       Reaktiva Chile
# 8                         22           6:39:08 h    Puro Trail Osorno
# 9                         22           6:45:11 h  Marlene Flores Team
#
#   Athlete country  Athlete year of birth Athlete gender Athlete age category  \
# 0             CHI                 1978.0              M                  M35
# 1             CHI                 1981.0              M                  M35
# 2             CHI                 1987.0              M                  M23
# 3             ARG                 1976.0              M                  M40
# 4             CHI                 1992.0              M                  M23
# 5             ARG                 1974.0              M                  M40
# 6             ARG                 1979.0              F                  W35
# 7             CHI                 1967.0              F                  W50
# 8             CHI                 1985.0              M                  M23
# 9             CHI                 1976.0              M                  M40
#
#   Athlete average speed  Athlete ID
# 0                10.286         0.0
# 1                 9.501         1.0
# 2                 9.472         2.0
# 3                 8.976         3.0
# 4                 8.469         4.0
# 5                 7.792         5.0
# 6                 7.732         6.0
# 7                 7.645         7.0
# 8                 7.516         8.0
# 9                 7.404         9.0

# %%
df.shape
# Out:
# (3959123, 13)

# %%
df.dtypes
# Out:
# Year of event                  int64
# Event dates                   object
# Event name                    object
# Event distance/length         object
# Event number of finishers      int64
# Athlete performance           object
# Athlete club                  object
# Athlete country               object
# Athlete year of birth        float64
# Athlete gender                object
# Athlete age category          object
# Athlete average speed         object
# Athlete ID                   float64
# dtype: object

# %%
##Data Cleanup
##Only Usa Races,50k or 50mi, 2020

##Show 50km or 50mi

#df[df['Event distance/length'] == '50km']
df[df['Event distance/length'] == '50mi']
# Out:
#          Year of event     Event dates  \
# 55                2018      06.01.2018
# 56                2018      06.01.2018
# 57                2018      06.01.2018
# 58                2018      06.01.2018
# 59                2018      06.01.2018
# ...                ...             ...
# 3958661           1997  30.-31.08.1997
# 3958662           1997  30.-31.08.1997
# 3958663           1997  30.-31.08.1997
# 3958664           1997  30.-31.08.1997
# 3958665           1997  30.-31.08.1997
#
#                                             Event name Event distance/length  \
# 55       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 56       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 57       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 58       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# 59       Yankee Springs 50 Mile Winter Challenge (USA)                  50mi
# ...                                                ...                   ...
# 3958661           Haliburton Forest 50 Mile Race (CAN)                  50mi
# 3958662           Haliburton Forest 50 Mile Race (CAN)                  50mi
# 3958663           Haliburton Forest 50 Mile Race (CAN)                  50mi
# 3958664           Haliburton Forest 50 Mile Race (CAN)                  50mi
# 3958665           Haliburton Forest 50 Mile Race (CAN)                  50mi
#
#          Event number of finishers Athlete performance          Athlete club  \
# 55                               9           9:53:05 h      *Middleville, MI
# 56                               9          11:09:35 h         *Waterloo, ON
# 57                               9          11:33:00 h        *Kitchener, ON
# 58                               9          11:38:17 h            *Utica, MI
# 59                               9          11:56:35 h       *Grass Lake, MI
# ...                            ...                 ...                   ...
# 3958661                         30          13:05:42 h             *Brampton
# 3958662                         30          13:05:42 h         *Hamilton, ON
# 3958663                         30          13:16:55 h  *Georgetown, ON, CAN
# 3958664                         30          13:16:56 h       *Bobcaygeon, ON
# 3958665                         30          13:58:26 h         *Hamilton, ON
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 55                  USA                 1983.0              M
# 56                  CAN                 1977.0              F
# 57                  CAN                 1976.0              M
# 58                  USA                 1986.0              M
# 59                  USA                 1988.0              M
# ...                 ...                    ...            ...
# 3958661             CAN                 1938.0              M
# 3958662             CAN                 1954.0              M
# 3958663             CAN                 1940.0              M
# 3958664             CAN                 1949.0              F
# 3958665             CAN                 1945.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 55                       M23                 8.141        55.0
# 56                       W40                 7.211        56.0
# 57                       M40                 6.967        57.0
# 58                       M23                 6.914        58.0
# 59                       M23                 6.738        59.0
# ...                      ...                   ...         ...
# 3958661                  M55                 6.145   1139964.0
# 3958662                  M40                 6.145   1113523.0
# 3958663                  M55                 6.058     99862.0
# 3958664                  W45                 6.058   1134591.0
# 3958665                  M50                 5.758   1127135.0
#
# [157627 rows x 13 columns]

# %%
df[df['Event distance/length'].isin(['50km', '50mi'])]
# Out:
#          Year of event Event dates                          Event name  \
# 0                 2018  06.01.2018                 Selva Costera (CHI)
# 1                 2018  06.01.2018                 Selva Costera (CHI)
# 2                 2018  06.01.2018                 Selva Costera (CHI)
# 3                 2018  06.01.2018                 Selva Costera (CHI)
# 4                 2018  06.01.2018                 Selva Costera (CHI)
# ...                ...         ...                                 ...
# 3958688           1997  30.08.1997  Haliburton Forest 50 km Race (CAN)
# 3958689           1997  30.08.1997  Haliburton Forest 50 km Race (CAN)
# 3958690           1997  30.08.1997  Haliburton Forest 50 km Race (CAN)
# 3958745           1997  24.08.1997         Subida al Pico Veleta (ESP)
# 3958746           1997  24.08.1997         Subida al Pico Veleta (ESP)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 0                        50km                         22           4:51:39 h
# 1                        50km                         22           5:15:45 h
# 2                        50km                         22           5:16:44 h
# 3                        50km                         22           5:34:13 h
# 4                        50km                         22           5:54:14 h
# ...                       ...                        ...                 ...
# 3958688                  50km                         25           7:20:08 h
# 3958689                  50km                         25           7:26:31 h
# 3958690                  50km                         25           8:58:30 h
# 3958745                  50km                          2           4:11:19 h
# 3958746                  50km                          2           5:38:42 h
#
#                 Athlete club Athlete country  Athlete year of birth  \
# 0                      Tnfrc             CHI                 1978.0
# 1         Roberto Echeverría             CHI                 1981.0
# 2          Puro Trail Osorno             CHI                 1987.0
# 3                   Columbia             ARG                 1976.0
# 4             Baguales Trail             CHI                 1992.0
# ...                      ...             ...                    ...
# 3958688  *St. Catharines, ON             CAN                 1933.0
# 3958689          *Fergus, ON             CAN                 1956.0
# 3958690      *Burlington, ON             CAN                 1946.0
# 3958745      Memorial Santos             BRA                 1964.0
# 3958746  Atletismo Rio Dilar             ESP                    NaN
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 0                    M                  M35                10.286         0.0
# 1                    M                  M35                 9.501         1.0
# 2                    M                  M23                 9.472         2.0
# 3                    M                  M40                 8.976         3.0
# 4                    M                  M23                 8.469         4.0
# ...                ...                  ...                   ...         ...
# 3958688              M                  M60                 6.816   1142029.0
# 3958689              F                  W40                 6.719   1139970.0
# 3958690              M                  M50                 5.571   1126746.0
# 3958745              M                  M23                11.937    347109.0
# 3958746              F                  NaN                 8.857   1160634.0
#
# [975071 rows x 13 columns]

# %%
df[(df['Event distance/length'].isin(['50km','50mi'])) & (df['Year of event'] == 2020)]
# Out:
#          Year of event     Event dates  \
# 2538571           2020  07.-09.02.2020
# 2538572           2020  07.-09.02.2020
# 2538573           2020  07.-09.02.2020
# 2538574           2020  07.-09.02.2020
# 2538575           2020  07.-09.02.2020
# ...                ...             ...
# 2762404           2020      03.10.2020
# 2762405           2020      03.10.2020
# 2762406           2020      03.10.2020
# 2762407           2020      03.10.2020
# 2762408           2020      03.10.2020
#
#                                       Event name Event distance/length  \
# 2538571  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538572  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538573  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538574  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# 2538575  Taipei 48hr Ultra Marathon - 50mi (TPE)                  50mi
# ...                                          ...                   ...
# 2762404               Bison Ultra-Trail 50 (POL)                  50km
# 2762405               Bison Ultra-Trail 50 (POL)                  50km
# 2762406               Bison Ultra-Trail 50 (POL)                  50km
# 2762407               Bison Ultra-Trail 50 (POL)                  50km
# 2762408               Bison Ultra-Trail 50 (POL)                  50km
#
#          Event number of finishers Athlete performance          Athlete club  \
# 2538571                         38           7:34:19 h                   日本隊
# 2538572                         38           7:43:50 h                   NaN
# 2538573                         38           8:04:40 h                   NaN
# 2538574                         38           8:30:49 h             台灣大腳ㄚ長跑協會
# 2538575                         38           8:34:47 h                   NaN
# ...                            ...                 ...                   ...
# 2762404                        271           7:36:25 h  AKS Polonia Warszawa
# 2762405                        271           7:36:27 h             *Warszawa
# 2762406                        271           7:44:18 h      Outdoor Training
# 2762407                        271           8:04:50 h      PH Bysewo Gdańsk
# 2762408                        271           8:11:43 h    *Nowe Aleksandrowo
#
#         Athlete country  Athlete year of birth Athlete gender  \
# 2538571             JPN                 1965.0              M
# 2538572             AUS                 1974.0              M
# 2538573             TPE                 1976.0              M
# 2538574             TPE                 1969.0              F
# 2538575             TPE                 1964.0              M
# ...                 ...                    ...            ...
# 2762404             POL                 1981.0              F
# 2762405             POL                 1970.0              F
# 2762406             POL                 1993.0              F
# 2762407             POL                 1976.0              M
# 2762408             POL                 1961.0              M
#
#         Athlete age category Athlete average speed  Athlete ID
# 2538571                  M50                10.627     53107.0
# 2538572                  M45                10.409      8785.0
# 2538573                  M40                 9.962      4502.0
# 2538574                  W50                 9.452     63964.0
# 2538575                  M55                 9.379      4485.0
# ...                      ...                   ...         ...
# 2762404                  W35                 6.573    860743.0
# 2762405                  W45                 6.572    860744.0
# 2762406                  W23                 6.461    860745.0
# 2762407                  M40                 6.188    798409.0
# 2762408                  M55                 6.101    860746.0
#
# [63489 rows x 13 columns]

# %%
df[df['Event name'] == 'Everglades 50 Mile Ultra Run (USA)'] ['Event name'].str.split('(').str.get(1).str.split('(').str.get(0)
# Out:
# 51923      USA)
# 51924      USA)
# 51925      USA)
# 51926      USA)
# 51927      USA)
#            ...
# 2591511    USA)
# 2591512    USA)
# 2591513    USA)
# 2591514    USA)
# 2591515    USA)
# Name: Event name, Length: 190, dtype: object

# %%
###Shows all events that took placein the USA
df[df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA']
# Out:
#          Year of event Event dates  \
# 55                2018  06.01.2018
# 56                2018  06.01.2018
# 57                2018  06.01.2018
# 58                2018  06.01.2018
# 59                2018  06.01.2018
# ...                ...         ...
# 3958620           1997  31.08.1997
# 3958621           1997  31.08.1997
# 3958622           1997  31.08.1997
# 3958623           1997  31.08.1997
# 3958624           1997  31.08.1997
#
#                                                Event name  \
# 55          Yankee Springs 50 Mile Winter Challenge (USA)
# 56          Yankee Springs 50 Mile Winter Challenge (USA)
# 57          Yankee Springs 50 Mile Winter Challenge (USA)
# 58          Yankee Springs 50 Mile Winter Challenge (USA)
# 59          Yankee Springs 50 Mile Winter Challenge (USA)
# ...                                                   ...
# 3958620  Cirulnick-Innamorato Six Hour Distance Run (USA)
# 3958621  Cirulnick-Innamorato Six Hour Distance Run (USA)
# 3958622  Cirulnick-Innamorato Six Hour Distance Run (USA)
# 3958623  Cirulnick-Innamorato Six Hour Distance Run (USA)
# 3958624  Cirulnick-Innamorato Six Hour Distance Run (USA)
#
#         Event distance/length  Event number of finishers Athlete performance  \
# 55                       50mi                          9           9:53:05 h
# 56                       50mi                          9          11:09:35 h
# 57                       50mi                          9          11:33:00 h
# 58                       50mi                          9          11:38:17 h
# 59                       50mi                          9          11:56:35 h
# ...                       ...                        ...                 ...
# 3958620                    6h                         25           51.121 km
# 3958621                    6h                         25           50.776 km
# 3958622                    6h                         25           50.603 km
# 3958623                    6h                         25           49.624 km
# 3958624                    6h                         25           49.506 km
#
#              Athlete club Athlete country  Athlete year of birth  \
# 55       *Middleville, MI             USA                 1983.0
# 56          *Waterloo, ON             CAN                 1977.0
# 57         *Kitchener, ON             CAN                 1976.0
# 58             *Utica, MI             USA                 1986.0
# 59        *Grass Lake, MI             USA                 1988.0
# ...                   ...             ...                    ...
# 3958620               NaN             USA                 1957.0
# 3958621               *NJ             USA                 1935.0
# 3958622               NaN             USA                 1959.0
# 3958623               NaN             USA                 1966.0
# 3958624               NaN             USA                 1943.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 55                   M                  M23                 8.141        55.0
# 56                   F                  W40                 7.211        56.0
# 57                   M                  M40                 6.967        57.0
# 58                   M                  M23                 6.914        58.0
# 59                   M                  M23                 6.738        59.0
# ...                ...                  ...                   ...         ...
# 3958620              F                  W35                  8.52   1158663.0
# 3958621              M                  M60                 8.463   1138616.0
# 3958622              F                  W35                 8.434   1160008.0
# 3958623              M                  M23                 8.271   1160604.0
# 3958624              F                  W50                 8.251   1160605.0
#
# [693177 rows x 13 columns]

# %%
df[
    (df['Event distance/length'].isin(['50km', '50mi'])) &
    (df['Year of event'] == 2020) &
    (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')
]
# Out:
#          Year of event Event dates  \
# 2539945           2020  02.02.2020
# 2539946           2020  02.02.2020
# 2539947           2020  02.02.2020
# 2539948           2020  02.02.2020
# 2539949           2020  02.02.2020
# ...                ...         ...
# 2760957           2020  03.10.2020
# 2760958           2020  03.10.2020
# 2760959           2020  03.10.2020
# 2760960           2020  03.10.2020
# 2760961           2020  03.10.2020
#
#                                             Event name Event distance/length  \
# 2539945  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539946  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539947  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539948  West Seattle Beach Run - Winter Edition (USA)                  50km
# 2539949  West Seattle Beach Run - Winter Edition (USA)                  50km
# ...                                                ...                   ...
# 2760957   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760958   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760959   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760960   Yankee Springs Fall Trail Run Festival (USA)                  50km
# 2760961   Yankee Springs Fall Trail Run Festival (USA)                  50km
#
#          Event number of finishers Athlete performance  \
# 2539945                         20           3:17:55 h
# 2539946                         20           4:02:32 h
# 2539947                         20           4:07:57 h
# 2539948                         20           4:22:02 h
# 2539949                         20           4:27:34 h
# ...                            ...                 ...
# 2760957                         30           7:07:48 h
# 2760958                         30           7:27:22 h
# 2760959                         30           7:27:24 h
# 2760960                         30           7:38:30 h
# 2760961                         30           7:59:53 h
#
#                    Athlete club Athlete country  Athlete year of birth  \
# 2539945      *Normandy Park, WA             USA                 1991.0
# 2539946           *Gold Bar, WA             USA                 1981.0
# 2539947             *Vashon, WA             USA                 1999.0
# 2539948         *Gig Harbor, WA             USA                 1983.0
# 2539949  *Bainbridge Island, WA             USA                 1977.0
# ...                         ...             ...                    ...
# 2760957       *East Lansing, MI             USA                 1958.0
# 2760958      *Traverse City, MI             USA                 1977.0
# 2760959      *Traverse City, MI             USA                 1962.0
# 2760960              *Mason, MI             USA                 1981.0
# 2760961                     NaN             USA                 1980.0
#
#         Athlete gender Athlete age category Athlete average speed  Athlete ID
# 2539945              M                  M23                15.158     71287.0
# 2539946              M                  M35                12.369    629508.0
# 2539947              M                 MU23                12.099     64838.0
# 2539948              M                  M35                11.449    704450.0
# 2539949              M                  M40                11.212    810281.0
# ...                ...                  ...                   ...         ...
# 2760957              F                  W60                 7.013    816361.0
# 2760958              F                  W40                 6.706    326469.0
# 2760959              F                  W55                 6.705    372174.0
# 2760960              F                  W35                 6.543    860349.0
# 2760961              M                  M35                 6.252    770097.0
#
# [26090 rows x 13 columns]

# %%
df2 = df[
    (df['Event distance/length'].isin(['50km', '50mi'])) &
    (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')
]
df2.head()
# Out:
#     Year of event Event dates                                     Event name  \
# 55           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 56           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 57           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 58           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
# 59           2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge (USA)
#
#    Event distance/length  Event number of finishers Athlete performance  \
# 55                  50mi                          9           9:53:05 h
# 56                  50mi                          9          11:09:35 h
# 57                  50mi                          9          11:33:00 h
# 58                  50mi                          9          11:38:17 h
# 59                  50mi                          9          11:56:35 h
#
#         Athlete club Athlete country  Athlete year of birth Athlete gender  \
# 55  *Middleville, MI             USA                 1983.0              M
# 56     *Waterloo, ON             CAN                 1977.0              F
# 57    *Kitchener, ON             CAN                 1976.0              M
# 58        *Utica, MI             USA                 1986.0              M
# 59   *Grass Lake, MI             USA                 1988.0              M
#
#    Athlete age category Athlete average speed  Athlete ID
# 55                  M23                 8.141        55.0
# 56                  W40                 7.211        56.0
# 57                  M40                 6.967        57.0
# 58                  M23                 6.914        58.0
# 59                  M23                 6.738        59.0

# %%
df2 = df[
    (df['Event distance/length'].isin(['50km', '50mi'])) &
    (df['Event name'].str.split('(').str.get(1).str.split(')').str.get(0) == 'USA')
].copy()
df2['Event name'] = df2['Event name'].str.split('(').str.get(0)
df2['athlete_age'] = 2020 - df2['Athlete year of birth']
df2['Athlete performance'] = df2['Athlete performance'].str.split('h').str.get(0)
df2 = df2.drop(columns=['Athlete club', 'Athlete country', 'Athlete year of birth', 'Athlete age category'], axis = 1)

# Convert 'Athlete average speed' to numeric, coercing errors to NaN
df2['Athlete average speed'] = pd.to_numeric(df2['Athlete average speed'], errors='coerce')

# Drop rows with NaN values, including those introduced by the conversion
df2 = df2.dropna()
df2 = df2.reset_index(drop = True)

df2['athlete_age'] = df2['athlete_age'].astype(int)

df2 = df2.rename(columns = {
                            'Year of event': 'year',
                            'Event dates': 'race_day',
                            'Event name': 'race_name',
                            'Event distance/length': 'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id'
                            })
df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance','athlete_average_speed']]
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')

# %%
import seaborn as sns
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
df2.shape
# Out:
# (422188, 10)

# %%
##remove [USA] from event name
df2['race_name'].str.split('(').str.get(0)
# Out:
# 0         Yankee Springs 50 Mile Winter Challenge
# 1         Yankee Springs 50 Mile Winter Challenge
# 2         Yankee Springs 50 Mile Winter Challenge
# 3         Yankee Springs 50 Mile Winter Challenge
# 4         Yankee Springs 50 Mile Winter Challenge
#                             ...
# 422183                       Run On The Sly 50 Km
# 422184                       Run On The Sly 50 Km
# 422185                       Run On The Sly 50 Km
# 422186                       Run On The Sly 50 Km
# 422187                       Run On The Sly 50 Km
# Name: race_name, Length: 422188, dtype: object

# %%
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
df2['race_name'] = df2['race_name'].str.split('(').str.get(0)

# %%
##USA is gone
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
##Athlete age cleanup

# %%
##remove  h from athlete performance

# %%
df2.head(5)
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
df2.columns
# Out:
# Index(['year', 'race_day', 'race_name', 'race_length',
#        'race_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_average_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
##drop columns: Athlete Club, Athlete Country, Athlete year of birth, Athlete Age Category

# %%
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
##Clean up null values
df2.isna().sum()
# Out:
# year                        0
# race_day                    0
# race_name                   0
# race_length                 0
# race_number_of_finishers    0
# athlete_performance         0
# athlete_gender              0
# athlete_average_speed       0
# athlete_id                  0
# athlete_age                 0
# dtype: int64

# %%
df2[df2['athlete_age'].isna()==1]
# Out:
# Empty DataFrame
# Columns: [year, race_day, race_name, race_length, race_number_of_finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete_age]
# Index: []

# %%
df2 = df2.dropna()
df2.shape
# Out:
# (422188, 10)

# %%
##Check for duplicated
df2[df2.duplicated() == True]
# Out:
# Empty DataFrame
# Columns: [year, race_day, race_name, race_length, race_number_of_finishers, athlete_performance, athlete_gender, athlete_average_speed, athlete_id, athlete_age]
# Index: []

# %%
##reset {index
df2.reset_index(drop = True)
# Out:
#         year    race_day                                 race_name  \
# 0       2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 1       2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 2       2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 3       2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# 4       2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge
# ...      ...         ...                                       ...
# 422183  1997  31.08.1997                     Run On The Sly 50 Km
# 422184  1997  31.08.1997                     Run On The Sly 50 Km
# 422185  1997  31.08.1997                     Run On The Sly 50 Km
# 422186  1997  31.08.1997                     Run On The Sly 50 Km
# 422187  1997  31.08.1997                     Run On The Sly 50 Km
#
#        race_length  race_number_of_finishers athlete_performance  \
# 0             50mi                         9            9:53:05
# 1             50mi                         9           11:09:35
# 2             50mi                         9           11:33:00
# 3             50mi                         9           11:38:17
# 4             50mi                         9           11:56:35
# ...            ...                       ...                 ...
# 422183        50km                        89            9:22:26
# 422184        50km                        89            9:41:52
# 422185        50km                        89            9:41:54
# 422186        50km                        89            9:47:17
# 422187        50km                        89           10:29:15
#
#        athlete_gender  athlete_average_speed  athlete_id  athlete_age
# 0                   M                  8.141        55.0           37
# 1                   F                  7.211        56.0           43
# 2                   M                  6.967        57.0           44
# 3                   M                  6.914        58.0           34
# 4                   M                  6.738        59.0           32
# ...               ...                    ...         ...          ...
# 422183              F                  5.334   1157715.0           88
# 422184              F                  5.156   1140125.0           66
# 422185              F                  5.156   1142703.0           78
# 422186              F                  5.108   1157716.0           96
# 422187              F                  4.768   1142551.0           72
#
# [422188 rows x 10 columns]

# %%
##fix types
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# athlete_gender               object
# athlete_average_speed       float64
# athlete_id                  float64
# athlete_age                   int64
# dtype: object

# %%
df2['athlete_age'] = df2['athlete_age'].astype(int)

# %%
#average speed

# %%
df2.dtypes
# Out:
# year                          int64
# race_day                     object
# race_name                    object
# race_length                  object
# race_number_of_finishers      int64
# athlete_performance          object
# athlete_gender               object
# athlete_average_speed       float64
# athlete_id                  float64
# athlete_age                   int64
# dtype: object

# %%
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
##rename columns
#Year of event 	int64
#Event dates 	object
#Event name 	object
#Event distance/length 	object
#Event number of finishers 	int64
#Athlete performance 	object
#Athlete gender 	object
#Athlete average speed 	float64
#Athlete ID 	int64
#athlete_age 	int64

# %%
df2 = df2.rename(columns = {'Year of event': 'year',
                            'Event dates': 'race_day',
                            'Event name': 'race_name',
                            'Event distance/length': 'race_length',
                            'Event number of finishers': 'race_number_of_finishers',
                            'Athlete performance': 'athlete_performance',
                            'Athlete gender': 'athlete_gender',
                            'Athlete average speed': 'athlete_average_speed',
                            'Athlete ID': 'athlete_id',
                            })

# %%
df2.head()
# Out:
#    year    race_day                                 race_name race_length  \
# 0  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  2018  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers athlete_performance athlete_gender  \
# 0                         9            9:53:05               M
# 1                         9           11:09:35               F
# 2                         9           11:33:00               M
# 3                         9           11:38:17               M
# 4                         9           11:56:35               M
#
#    athlete_average_speed  athlete_id  athlete_age
# 0                  8.141        55.0           37
# 1                  7.211        56.0           43
# 2                  6.967        57.0           44
# 3                  6.914        58.0           34
# 4                  6.738        59.0           32

# %%
df2.columns
# Out:
# Index(['year', 'race_day', 'race_name', 'race_length',
#        'race_number_of_finishers', 'athlete_performance', 'athlete_gender',
#        'athlete_average_speed', 'athlete_id', 'athlete_age'],
#       dtype='object')

# %%
#reorder columns
df3 = df3 = df2[['race_day', 'race_name', 'race_length', 'race_number_of_finishers', 'athlete_id', 'athlete_gender', 'athlete_age', 'athlete_performance','athlete_average_speed']]

# %%
df3.head()
# Out:
#      race_day                                 race_name race_length  \
# 0  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4  06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
#
#    race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                         9        55.0              M           37
# 1                         9        56.0              F           43
# 2                         9        57.0              M           44
# 3                         9        58.0              M           34
# 4                         9        59.0              M           32
#
#   athlete_performance  athlete_average_speed
# 0            9:53:05                   8.141
# 1           11:09:35                   7.211
# 2           11:33:00                   6.967
# 3           11:38:17                   6.914
# 4           11:56:35                   6.738

# %%
#charts and graphs

# %%
sns.histplot(df3['race_length'])
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
#to overlay males vs females
sns.histplot(df3, x = 'race_length', hue = 'athlete_gender')
# Out:
# <Axes: xlabel='race_length', ylabel='Count'>

# %%
sns.displot(df3[df3['race_length'] == '50mi'] ['athlete_average_speed'])

# %%
sns.violinplot(data = df3, x='race_length', y='athlete_average_speed', hue = 'athlete_gender', split = True, inner = 'quarts', linewidth = 1)
# Out:
# <Axes: xlabel='race_length', ylabel='athlete_average_speed'>

# %%
sns.lmplot(data=df3, x= 'athlete_age', y= 'athlete_average_speed', hue = 'athlete_gender')

# %%
#questions I want to find out from the data
##rename columns
#Year of event 	int64
#Event dates 	object
#Event name 	object
#Event distance/length 	object
#Event number of finishers 	int64
#Athlete performance 	object
#Athlete gender 	object
#Athlete average speed 	float64
#Athlete ID 	int64
#athlete_age 	int64

# %%
#Difference in speed for the 50k,50mi male to female

# %%
df3.groupby(['race_length', 'athlete_gender'])['athlete_average_speed'].mean()
# Out:
# race_length  athlete_gender
# 50km         F                 7.018501
#              M                 7.740733
#              X                 7.487182
# 50mi         F                 6.936878
#              M                 7.660835
#              X                 6.925600
# Name: athlete_average_speed, dtype: float64

# %%
#what age groups are the best in the 50m race? (20 + races min) show 15

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False).query('count > 19').head(15)
# Out:
#                  mean  count
# athlete_age
# 82           9.279641    490
# 76           9.137338    846
# 84           9.111160    307
# 78           9.077727    662
# 72           9.075684    995
# 69           9.024431    944
# 73           9.004847   1023
# 77           8.953269    843
# 98           8.875839     62
# 74           8.854601    966
# 75           8.847722    709
# 102          8.836955     22
# 87           8.827832    273
# 71           8.793646    873
# 80           8.742377    589

# %%
#what age groups are the worst in the 50m race? (10 + races min) show 20

# %%
df3.query('race_length == "50mi"').groupby('athlete_age')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = True).query('count > 9').head(20)
# Out:
#                  mean  count
# athlete_age
# 14           5.225500     14
# 13           5.924818     11
# 16           6.626000     49
# 108          6.822739     23
# 50           6.878017   2838
# 54           6.939495   1902
# 57           6.955868   1557
# 49           6.963410   2848
# 53           6.972035   2075
# 15           6.975818     22
# 51           6.983285   2592
# 48           6.990685   2844
# 105          6.999667     39
# 52           7.007681   2354
# 58           7.012053   1592
# 56           7.060450   1569
# 46           7.071393   3171
# 45           7.074350   3288
# 55           7.108544   1737
# 47           7.115079   2898

# %%
#seasons for the data -> Slower in summer than winter?

#spring 3-5
#summer 6-8
#fall 9-11
#winter 12-2

#aplit between two decimals

# %%
df3['race_month'] = df3['race_day'].str.split('.').str.get(1).astype(int)

# %%
#Race seasons
df3['race_season'] = df3['race_month'].apply(lambda x: 'Winter' if x > 11 else 'Fall' if x > 8 else 'Summer' if x > 5 else 'Spring' if x > 2 else 'Winter')
df3.head(25)
# Out:
#       race_day                                 race_name race_length  \
# 0   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 1   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 2   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 3   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 4   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 5   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 6   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 7   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 8   06.01.2018  Yankee Springs 50 Mile Winter Challenge         50mi
# 9   06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 10  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 11  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 12  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 13  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 14  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 15  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 16  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 17  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 18  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 19  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 20  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 21  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 22  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 23  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
# 24  06.01.2018    Yankee Springs 50 km Winter Challenge         50km
#
#     race_number_of_finishers  athlete_id athlete_gender  athlete_age  \
# 0                          9        55.0              M           37
# 1                          9        56.0              F           43
# 2                          9        57.0              M           44
# 3                          9        58.0              M           34
# 4                          9        59.0              M           32
# 5                          9        60.0              M           25
# 6                          9        61.0              M           41
# 7                          9        62.0              F           43
# 8                          9        63.0              F           30
# 9                         36        64.0              F           29
# 10                        36        65.0              M           44
# 11                        36        66.0              F           28
# 12                        36        67.0              M           33
# 13                        36        68.0              M           56
# 14                        36        69.0              M           55
# 15                        36        70.0              M           34
# 16                        36        71.0              M           44
# 17                        36        72.0              M           50
# 18                        36        73.0              M           42
# 19                        36        74.0              M           36
# 20                        36        75.0              M           24
# 21                        36        76.0              M           52
# 22                        36        77.0              M           42
# 23                        36        78.0              M           42
# 24                        36        79.0              M           42
#
#    athlete_performance  athlete_average_speed  race_month race_season
# 0             9:53:05                   8.141           1      Winter
# 1            11:09:35                   7.211           1      Winter
# 2            11:33:00                   6.967           1      Winter
# 3            11:38:17                   6.914           1      Winter
# 4            11:56:35                   6.738           1      Winter
# 5            12:32:16                   6.418           1      Winter
# 6            12:39:36                   6.356           1      Winter
# 7            12:39:36                   6.356           1      Winter
# 8            13:24:05                   6.004           1      Winter
# 9             5:09:40                   9.688           1      Winter
# 10            6:00:47                   8.315           1      Winter
# 11            6:02:02                   8.287           1      Winter
# 12            6:02:44                   8.271           1      Winter
# 13            6:10:30                   8.097           1      Winter
# 14            6:10:52                   8.089           1      Winter
# 15            6:11:43                   8.071           1      Winter
# 16            6:13:27                   8.033           1      Winter
# 17            6:27:42                   7.738           1      Winter
# 18            6:28:09                   7.729           1      Winter
# 19            6:29:36                   7.700           1      Winter
# 20            6:32:04                   7.652           1      Winter
# 21            6:36:39                   7.563           1      Winter
# 22            6:36:46                   7.561           1      Winter
# 23            6:40:07                   7.498           1      Winter
# 24            6:52:26                   7.274           1      Winter

# %%
df3.groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean   count
# race_season
# Winter       7.597994   93535
# Spring       7.564696  125921
# Fall         7.503332  127258
# Summer       7.169980   75474

# %%
#50 miler only
df3.query('`race_length` == "50mi"').groupby('race_season')['athlete_average_speed'].agg(['mean', 'count']).sort_values('mean', ascending = False)
# Out:
#                  mean  count
# race_season
# Fall         7.847929  36543
# Spring       7.535908  35005
# Winter       7.238353  25775
# Summer       6.951823  20257
